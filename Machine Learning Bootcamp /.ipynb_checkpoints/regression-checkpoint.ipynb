# %%
## Regression analysis with ML 
import numpy as np 
import pandas as pd 

data = pd.read_csv("data_car.csv")
data.head(10)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
# 5  BMW    1 Series  2012  premium unleaded (required)      230.0
# 6  BMW    1 Series  2012  premium unleaded (required)      300.0
# 7  BMW    1 Series  2012  premium unleaded (required)      300.0
# 8  BMW    1 Series  2012  premium unleaded (required)      230.0
# 9  BMW    1 Series  2013  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# ...

# %%
### Data Cleaning 

data.columns = data.columns.str.replace(" ", "_") 
data
# Out:
#           Make       Model  Year                Engine_Fuel_Type  Engine_HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
string = list(data.dtypes[data.dtypes==object].index)
string
# Out:
# ['Make',
#  'Model',
#  'Engine_Fuel_Type',
#  'Transmission_Type',
#  'Driven_Wheels',
#  'Market_Category',
#  'Vehicle_Size',
#  'Vehicle_Style']

# %%
for i in string:
    data[i]=data[i].str.lower().str.replace(" ", "_")

data
# Out:
#           Make       Model  Year                Engine_Fuel_Type  Engine_HP  \
# 0          bmw  1_series_m  2011     premium_unleaded_(required)      335.0
# 1          bmw    1_series  2011     premium_unleaded_(required)      300.0
# 2          bmw    1_series  2011     premium_unleaded_(required)      300.0
# 3          bmw    1_series  2011     premium_unleaded_(required)      230.0
# 4          bmw    1_series  2011     premium_unleaded_(required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    acura         zdx  2012     premium_unleaded_(required)      300.0
# 11910    acura         zdx  2012     premium_unleaded_(required)      300.0
# 11911    acura         zdx  2012     premium_unleaded_(required)      300.0
# 11912    acura         zdx  2013  premium_unleaded_(recommended)      300.0
# 11913  lincoln      zephyr  2006                regular_unleaded      221.0
#
# ...

# %%
data.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine_Fuel_Type      object
# Engine_HP            float64
# Engine_Cylinders     float64
# Transmission_Type     object
# Driven_Wheels         object
# Number_of_Doors      float64
# Market_Category       object
# Vehicle_Size          object
# Vehicle_Style         object
# highway_MPG            int64
# city_mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
data["Year"]=pd.to_datetime(data["Year"], format="%Y")

# %%
### Exploratory Data analysis  
data.describe()
# Out:
#                                 Year    Engine_HP  Engine_Cylinders  \
# count                          11914  11845.00000      11884.000000
# mean   2010-05-21 05:23:26.278328064    249.38607          5.628829
# min              1990-01-01 00:00:00     55.00000          0.000000
# 25%              2007-01-01 00:00:00    170.00000          4.000000
# 50%              2015-01-01 00:00:00    227.00000          6.000000
# 75%              2016-01-01 00:00:00    300.00000          6.000000
# max              2017-01-01 00:00:00   1001.00000         16.000000
# std                              NaN    109.19187          1.780559
#
#        Number_of_Doors   highway_MPG      city_mpg    Popularity          MSRP
# count     11908.000000  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean          3.436093     26.637485     19.733255   1554.911197  4.059474e+04
# min           2.000000     12.000000      7.000000      2.000000  2.000000e+03
# ...

# %%
for i in data.columns:
    print(i)
    print(data[i].unique()[:5])
    print()
# Out:
# Make
# ['bmw' 'audi' 'fiat' 'mercedes-benz' 'chrysler']
#
# Model
# ['1_series_m' '1_series' '100' '124_spider' '190-class']
#
# Year
# <DatetimeArray>
# ['2011-01-01 00:00:00', '2012-01-01 00:00:00', '2013-01-01 00:00:00',
#  '1992-01-01 00:00:00', '1993-01-01 00:00:00']
# Length: 5, dtype: datetime64[ns]
#
# Engine_Fuel_Type
# ['premium_unleaded_(required)' 'regular_unleaded'
#  'premium_unleaded_(recommended)' 'flex-fuel_(unleaded/e85)' 'diesel']
#
# Engine_HP
# [335. 300. 230. 320. 172.]
#
# Engine_Cylinders
# [ 6.  4.  5.  8. 12.]
#
# Transmission_Type
# ['manual' 'automatic' 'automated_manual' 'direct_drive' 'unknown']
#
# Driven_Wheels
# ['rear_wheel_drive' 'front_wheel_drive' 'all_wheel_drive'
#  'four_wheel_drive']
#
# Number_of_Doors
# [ 2.  4.  3. nan]
#
# Market_Category
# ['factory_tuner,luxury,high-performance' 'luxury,performance'
#  'luxury,high-performance' 'luxury' 'performance']
#
# Vehicle_Size
# ['compact' 'midsize' 'large']
#
# Vehicle_Style
# ...

# %%
#distribution of prices 
import matplotlib.pyplot as plt 
import seaborn as sns 

# %matplotlib inline

# %%
data.dtypes
# Out:
# Make                         object
# Model                        object
# Year                 datetime64[ns]
# Engine_Fuel_Type             object
# Engine_HP                   float64
# Engine_Cylinders            float64
# Transmission_Type            object
# Driven_Wheels                object
# Number_of_Doors             float64
# Market_Category              object
# Vehicle_Size                 object
# Vehicle_Style                object
# highway_MPG                   int64
# city_mpg                      int64
# Popularity                    int64
# MSRP                          int64
# dtype: object

# %%
nontext_data = list(data.columns[data.dtypes!="object"])[1:]
nontext_data
# Out:
# ['Engine_HP',
#  'Engine_Cylinders',
#  'Number_of_Doors',
#  'highway_MPG',
#  'city_mpg',
#  'Popularity',
#  'MSRP']

# %%
print(sns.histplot(data["MSRP"], bins =100))
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
log_prices =np.log1p(data.MSRP)
sns.histplot(log_prices)
# Out:
# <Axes: xlabel='MSRP', ylabel='Count'>

# %%
print(sns.histplot(data["Engine_HP"], bins =100))
# Out:
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)

# %%
## Missing Values 

data.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine_Fuel_Type        3
# Engine_HP              69
# Engine_Cylinders       30
# Transmission_Type       0
# Driven_Wheels           0
# Number_of_Doors         6
# Market_Category      3742
# Vehicle_Size            0
# Vehicle_Style           0
# highway_MPG             0
# city_mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
#settig up validation method 60%, 20%, 20% 
n=len(data)
n_val = int(n*.02)
n_test = int(n*0.2)
n_train = n-n_test-n_val

# %%
n_val, n_test, n_train
# Out:
# (238, 2382, 9294)

# %%
data_train=data.iloc[: n_train]
data_val=data.iloc[n_train:n_train+n_val ]
data_test=data.iloc[n_train+n_val: ]

# %%
### Set random number

idx =np.arange(n)
np.random.shuffle(idx)

# %%
## shuffling randomly using data 
data_train=data.iloc[idx[: n_train]]
data_val=data.iloc[idx[ n_train:n_train+n_val ]]
data_test=data.iloc[idx[n_train+n_val: ]]
